# %%
#Definicion de listas

lista_colores = ['Amarillo', 'azul', 'Rojo', 'negro']
print(lista_colores)
print(lista_colores[0])

#definicion de diccionarios
# nombre del diccionario = {'clave' : 'valor que guarda', 'clave1': 'valor1', 'clave2':valor2'}

info_estudiante = {'cuenta':'20162530037',
                  'nombre' : 'Gustavo',
                  'apellido': 'Gamero',
                  'telefono': '33394838'}

print(info_estudiante['telefono'])

#lista compuesta de diccionarios
lista_alumnos = [
    {
        'cuenta': 2012530034,
        'nombre': 'Gustavo',
        'Apellido': 'Gamero'
    },
    {
        'cuenta': 261535140022,
        'nombre': 'rtoberto',
        'Apellido': 'Carlo'
    },
    {
        'cuenta': 24234234234,
        'nombre': 'Juancito',
        'Apellido': 'Morazan',
        'telefono': '3123123'
    }
]

print(lista_alumnos[2]['telefono'])

# Diccionarios compuestos por listas

nombres= ['julia','juanito','Emmanue'] 
Profesiones= ['Maestro','Ingeniero','Doctor'] 
Telefonos= ['213132131','654645465','86465456']

Empleados={'nombre':nombres,
          'profesion': Profesiones,
          'Telefono':Telefonos}
print(Empleados['nombre'][2])


#importando pandas con alias pd

import pandas as pd

estructura_pd = pd.DataFrame(Empleados)

#Ingresando a una columana
print(estructura_pd['nombre'])

#Ingresando a una fila
print(estructura_pd.loc[1])


#Ejercicio> Crear un lista de diccionarios con 10 elementos cada valor del diccionario será: equipo, ganados, perdidos, empatados

equipos = [
    {
        'Equipo' : 'Real Espania',
        'Partidos Ganados' : 8,
        'Partidos Perdidos' : 1,
        'Partidos Empatados' : 2
    },
    {
        'Equipo' : 'Motagua',
        'Partidos Ganados' : 6,
        'Partidos Perdidos' : 3,
        'Partidos Empatados' : 1
    },
    {
        'Equipo' : 'Olimpia',
        'Partidos Ganados' : 5,
        'Partidos Perdidos' : 2,
        'Partidos Empatados' : 4
    },
    {
        'Equipo' : 'Marathon',
        'Partidos Ganados' : 4,
        'Partidos Perdidos' : 3,
        'Partidos Empatados' : 4
    },
    {
        'Equipo' : 'Victoria',
        'Partidos Ganados' : 4,
        'Partidos Perdidos' : 4,
        'Partidos Empatados' : 3
    },
    {
        'Equipo' : 'Olancho F.C',
        'Partidos Ganados' : 4,
        'Partidos Perdidos' : 5,
        'Partidos Empatados' : 2
    },
    {
        'Equipo' : 'Lobos UPNFM',
        'Partidos Ganados' : 4,
        'Partidos Perdidos' : 6,
        'Partidos Empatados' : 1
    },
    {
        'Equipo' : 'Juticalpa',
        'Partidos Ganados' : 2,
        'Partidos Perdidos' : 5,
        'Partidos Empatados' : 4
    },
    {
        'Equipo' : 'Real Sociedad',
        'Partidos Ganados' : 1,
        'Partidos Perdidos' : 4,
        'Partidos Empatados' : 6
    },
    {
        'Equipo' : 'Genesis',
        'Partidos Ganados' : 2,
        'Partidos Perdidos' : 6,
        'Partidos Empatados' : 3
    }
]


Equipos_pd = pd.DataFrame(equipos)
Equipos_pd

print(Equipos_pd['Equipo'])
print(Equipos_pd.loc[2])
# Out:
# ['Amarillo', 'azul', 'Rojo', 'negro']
# Amarillo
# 33394838
# 3123123
# Emmanue
# 0      julia
# 1    juanito
# 2    Emmanue
# Name: nombre, dtype: object
#     nombre  profesion   Telefono
# 1  juanito  Ingeniero  654645465
# 2  Emmanue     Doctor   86465456
# 0     Real Espania
# 1          Motagua
# 2          Olimpia
# 3         Marathon
# 4         Victoria
# 5      Olancho F.C
# 6      Lobos UPNFM
# 7        Juticalpa
# 8    Real Sociedad
# 9          Genesis
# Name: Equipo, dtype: object
# Equipo                Olimpia
# Partidos Ganados            5
# Partidos Perdidos           2
# Partidos Empatados          4
# Name: 2, dtype: object

# %%
print(estructura_pd.loc[0:3, 'nombre'])
# Out:
# 0      julia
# 1    juanito
# 2    Emmanue
# Name: nombre, dtype: object
