# %%
import pandas as pd
import numpy as py
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
#Ingresandon al archivo csv
df_datos = pd.read_csv('C:/users/tavog/train.csv')
df_datos
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
#Validando los datos
df_datos.TotRmsAbvGrd.isnull().sum() #Esta limpio
df_datos.LotFrontage.isnull().sum() #lo observo que si tiene valores nulos
df_datos.loc[df_datos['LotFrontage'].isnull(), 'LotFrontage'] = df_datos['LotFrontage'].mean() #Limpueza de valores cuando son nulos
df_datos.LotFrontage.isnull().sum() #lo observo que ya no tiene valores nulos
# Out:
# 0

# %%
#Dividiendo los datos entre las dimensiones/caracteristicas y lo que buscamos predecir (SalePrice)
X = df_datos[['LotArea','TotRmsAbvGrd','LotFrontage']]
y = df_datos['SalePrice']
#Asignando los valores de X y Y , asi como el tamanio de datos con lo que trabajaremos
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2)

# %%
#Creamos el modelo y lo ponemos a entrenar
modelo = LinearRegression()
modelo.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#Realizamos predicciones
y_predic = modelo.predict(X_test)

print('Valores predecidos por el modelo: \n', y_predic) # Valores predecidos en funcion del entrenamiento
print("Valores realies: \n", y_test.values) #valores reales
# Out:
# Valores predecidos por el modelo:
#  [196457.48556005 159336.82136696 125377.15396818 282909.20009511
#  187915.44813116 256464.9522607  147253.73504845 156714.19490105
#  167073.09163075 187242.7390067  141109.29784189 219759.56470214
#  192774.78800089 171836.39828323 278373.63370279 222259.76475151
#  145697.74390695 110719.21178553 167467.0125726  242133.46394007
#  201301.3631654   95274.70625609 227097.06232005 150043.12272669
#  214594.91933356 163002.31231913 214825.66641714 144951.12369004
#  164137.23504505 172966.40134248 187521.11515932 171765.326684
#  112184.65373714 150371.38813405 210903.21694966 145748.07467479
#  233986.0482022  166160.15247451 277114.03277123 218826.92719869
#  203068.74150315 199028.72084871 248769.27396941 185536.0566513
#  165747.62494712 143958.6553052  205647.5808781  250889.26447125
#  215199.82180904 144109.5646466  214654.49360793 269310.7844394
#  144414.83429498 210464.19003126 145973.86700112 162454.78296613
# ...

# %%
#evaluando rendimiento del modelo
ecm = mean_squared_error(y_test, y_predic)

r = r2_score(y_test, y_predic)
#ECM entre mas alto mejor
print("ECM: ",ecm)
#entre mas cercano a 1 seria mas presiso
print("r: ",r)
# Out:
# ECM:  5228604411.305551
# r:  0.30231692719054515
